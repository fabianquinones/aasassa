# %% [markdown]
# # Lluvias torrenciales, un desafío para las ciudades — ¿podrás evitar el diluvio?

# %% [markdown]
# ## Instrucciones
#
# 1. Lea detenidamente el enunciado y las preguntas.
# 2. Escriba sus desarrollos a continuación de la celda que dice “Desarrollo”.
# 3. Sus respuestas deben estar justificadas y su desarrollo debe ser ordenado y claro.
# 4. Se sugiere usar una celda de texto (markdown) con el número de la pregunta, una o más celdas de código para el desarrollo y luego una celda de texto (markdown) para escribir la respuesta.
# 5. Guarde su progreso antes de cerrar el programa.

# %% [markdown]
# ## Enunciado

# %% [markdown]
# En época invernal, es común que algunas ciudades experimenten lluvias intensas, lo que puede poner a prueba su infraestructura. Este año, ciudades como Valparaíso, Santiago y Concepción han registrado precipitaciones que requieren atención especial.
#
#
# Podemos representar la cantidad de agua acumulada en un día, en milímetros (mm), en cada ciudad con respecto al tiempo transcurrido en horas (t) a través de las siguientes funciones cuadráticas:
#
# **Valparaíso**: $$V(t)=0,7t^{2}+13,2t+39$$
#
# **Santiago**: $$S(t) =1,1t^{2}+15,8t+32$$
#
# **Concepción**: $$C(t) = 1,3t^{2}+18,9t+28$$
#
# Se sabe que los sistemas de alcantarillado de las ciudades no pueden acumular más de 95 mm de agua en un periodo de 4 horas. Si se supera este umbral, será necesario enviar equipos de emergencia para evitar inundaciones.
#
# Con ayuda de Python responde las siguientes preguntas:
#
# 1. ¿Cuál sería la cantidad de agua acumulada en cada una de las ciudades al cabo de 50 minutos?
# 1. Grafique las funciones respectivas.
# 1. Si la lluvia comenzó en Valparaíso a las 16:45 horas, en Santiago a las 17:15 horas y en Concepción a las 18:00 horas, ¿cuál será el total de agua caída a las 19:30 horas en cada ciudad?
# 1. ¿Después de cuánto tiempo cada ciudad requerirá por primera vez de la ayuda de los equipos de emergencia?
# 1. Se espera que la lluvia dure 12 horas ininterrumpidas. Para gestionar posibles emergencias, se dispondrá de dos equipos de intervención:
#    - El primer equipo trabajará durante las primeras 6 horas de lluvia.
#    - El segundo equipo tomará el relevo durante las últimas 6 horas.
#
#    Basándote en el comportamiento de la acumulación de agua en las ciudades de Valparaíso, Santiago y Concepción. Analiza cómo cambia la acumulación de agua en cada ciudad a lo largo del día. ¿Cuál equipo tendrá que ir a revisar el alcantarillado con mayor frecuencia debido a la acumulación de agua? Justifica tu respuesta considerando la forma de las funciones que describen la acumulación de agua.

# %% [markdown]
# ## Desarrollo

# %%
def agua(T,n1,n2,n3):
    return ("el resultado total de caida de agua es: ",(n1*T**2)+(n2+T)+(n3))
valpo =agua(0.83,0.7,13.2,39)
santiasco =agua(0.83, 1.1 , 15.8, 32)
conce= agua(0.83, 1.3, 18.9, 28)

print("el resultado de valpo es: ",valpo,"mm","\nel resultado de santiago es: ",santiasco,"mm","\nel resultado de conce es: ", conce,"mm")
# Out:
# el resultado de valpo es:  ('el resultado total de caida de agua es: ', 53.51223) mm
# el resultado de santiago es:  ('el resultado total de caida de agua es: ', 49.387789999999995) mm
# el resultado de conce es:  ('el resultado total de caida de agua es: ', 48.625569999999996) mm

# %% [markdown]
# 2

# %%
import matplotlib.pyplot as plt
import numpy as np

tiempo= np.arange(0,0.83,0.1)
valpoto=53.51*tiempo
santiago=49.38*tiempo
concepcion=48.62*tiempo

plt.plot(tiempo,valpoto, label ="valparaiso")
plt.plot(tiempo,santiago, label ="valparaiso")
plt.plot(tiempo,concepcion, label ="valparaiso")



plt.title('Relación entre cantidad de agua y el tiempo transcurrido')
plt.xlabel('Tiempo transcurrido (horas)')
plt.ylabel('cantidad agua (mm)')

plt.grid(True)
plt.show()

# %% [markdown]
# 3

# %%
def agua(T,n1,n2,n3):
    return ("el resultado total de caida de agua es: ",(n1*T**2)+(n2+T)+(n3))
valpo =agua(4.75,0.7,13.2,39)
santiasco =agua(2.25, 1.1 , 15.8, 32)
conce= agua(1.5, 1.3, 18.9, 28)

print("el resultado de valpo es: ",valpo,"mm","\nel resultado de santiago es: ",santiasco,"mm","\nel resultado de conce es: ", conce,"mm")
# Out:
# el resultado de valpo es:  ('el resultado total de caida de agua es: ', 72.74375) mm
# el resultado de santiago es:  ('el resultado total de caida de agua es: ', 55.618750000000006) mm
# el resultado de conce es:  ('el resultado total de caida de agua es: ', 51.325) mm

# %% [markdown]
# 4

# %%
def agua(T,n1,n2,n3):
    return ("el resultado total de caida de agua es: ",(n1*T**2)+(n2+T)+(n3))
valpo =agua(7.2,0.7,13.2,39)
santiasco =agua(6.1, 1.1 , 15.8, 32)
conce= agua(5.75, 1.3, 18.9, 28)

print("en valp llaman a las 7.2h trascurridas")
print("en santiago llaman a las 6.1h trascurridas")
print("en conce llaman a las 5.75h trascurridas")
# Out:
# el resultado de valpo es:  ('el resultado total de caida de agua es: ', 95.68799999999999) mm
# el resultado de santiago es:  ('el resultado total de caida de agua es: ', 94.83099999999999) mm
# el resultado de conce es:  ('el resultado total de caida de agua es: ', 95.63125) mm
